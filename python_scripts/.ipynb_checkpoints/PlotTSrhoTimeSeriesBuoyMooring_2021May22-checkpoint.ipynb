# %% [markdown]
# # readme
# descrip: plot temperature, salinity and density time series collected from buoy mooring at Gulf of Maine <br>
#
# update history: <br>
# v1.0 DL 2021Apr12 <br>
# v1.1 DL 2021May24 <br>
# v1.2 DL 2021May26 <br>
#
# extra notes: <br>
# paper mentioned mooring data (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5051723/) <br>
# paper suggests Gulf Stream rings causes cold intermediate water (https://agupubs.onlinelibrary.wiley.com/doi/epdf/10.1029/JC089iC04p06575) <br>
# mooring site (http://phog.umaine.edu/buoyhome.php) <br>
# http://phog.umaine.edu/data/gomoos/buoy/php/historical_rt_download.php?mooring_id=M0130&buffer_name=sbe37&project=gomoos <br>
# netcdf downloading site:
# http://gyre.umeoce.maine.edu/GoMoos/php/mooring_file_info.php?report=historical_files <br>

# %% [markdown]
# # import modules

# %%
# general python packages
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
# import proplot as plot
# import cartopy
# cartopy.config['pre_existing_data_dir']='/scratch/group/ihesp/shared/cartopy_features'
# import cartopy.crs as ccrs
# from cartopy.mpl.geoaxes import GeoAxes
# from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
# from mpl_toolkits.axes_grid1 import AxesGrid

# python GCM(POP) packages
# import xgcm
# import pop_tools
# import xoak
# import xesmf as xe
# import seawater as sw

# dask jupyter lab packages
# import dask
# from dask.distributed import Client
# from dask.distributed import performance_report

# file name with time packages
# from itertools import product
# from cftime import DatetimeNoLeap

# %% [markdown]
# # incorporate dask

# %%
# small data sets, no need to use dask

# %% [markdown]
# # load data files

# %%
# suffix 1, 20 means depth [m]
infile1 = ('/ihesp/user/dapengli/obs_dat/'
          'BuoyM0130_GulfOfMaine_2021May24/M01.sbe37.historical.1m.nc')
infile20 = ('/ihesp/user/dapengli/obs_dat/'
          'BuoyM0130_GulfOfMaine_2021May24/M01.sbe37.historical.20m.nc')
infile50 = ('/ihesp/user/dapengli/obs_dat/'
          'BuoyM0130_GulfOfMaine_2021May24/M01.sbe37.historical.50m.nc')
infile100 = ('/ihesp/user/dapengli/obs_dat/'
          'BuoyM0130_GulfOfMaine_2021May24/M01.sbe37.historical.100m.nc')
infile150 = ('/ihesp/user/dapengli/obs_dat/'
          'BuoyM0130_GulfOfMaine_2021May24/M01.sbe37.historical.150m.nc')
infile200 = ('/ihesp/user/dapengli/obs_dat/'
          'BuoyM0130_GulfOfMaine_2021May24/M01.sbe37.historical.200m.nc')
infile250 = ('/ihesp/user/dapengli/obs_dat/'
          'BuoyM0130_GulfOfMaine_2021May24/M01.sbe37.historical.250m.nc')

ds1_raw = xr.open_dataset(infile1)
print('time(1m sensor): ', ds1_raw.time[0].values,'-',ds1_raw.time[-1].values)
ds1 = ds1_raw.sel(time=slice('2004','2020'))

ds20_raw = xr.open_dataset(infile20)
print('time(20m sensor): ', ds20_raw.time[0].values,'-',ds20_raw.time[-1].values)
ds20 = ds20_raw.sel(time=slice('2004','2020'))

ds50_raw = xr.open_dataset(infile50)
print('time(50m sensor): ', ds50_raw.time[0].values,'-',ds50_raw.time[-1].values)
ds50 = ds50_raw.sel(time=slice('2004','2020'))

ds100_raw = xr.open_dataset(infile100)
print('time(100m sensor): ', ds100_raw.time[0].values,'-',ds100_raw.time[-1].values)
ds100 = ds100_raw.sel(time=slice('2004','2020'))

ds150_raw = xr.open_dataset(infile150)
print('time(150m sensor): ', ds150_raw.time[0].values,'-',ds150_raw.time[-1].values)
ds150 = ds150_raw.sel(time=slice('2004','2020'))

ds200_raw = xr.open_dataset(infile200)
print('time(200m sensor): ', ds200_raw.time[0].values,'-',ds200_raw.time[-1].values)
ds200 = ds200_raw.sel(time=slice('2004','2020'))

ds250_raw = xr.open_dataset(infile250)
print('time(250m sensor): ', ds250_raw.time[0].values,'-',ds250_raw.time[-1].values)
ds250 = ds250_raw.sel(time=slice('2004','2020'))

ds250
# Out:
# time(1m sensor):  2003-07-09T05:00:00.000013312 - 2021-04-09T13:30:00.000000000
# time(20m sensor):  2003-07-09T04:30:00.000000000 - 2021-04-09T13:30:00.000000000
# time(50m sensor):  2003-07-09T04:30:00.000000000 - 2021-02-20T09:30:00.000013312
# time(100m sensor):  2003-07-09T04:30:00.000000000 - 2021-04-09T14:00:00.000013312
# time(150m sensor):  2003-07-09T04:30:00.000000000 - 2021-02-18T02:00:00.000013312
# time(200m sensor):  2003-07-09T04:30:00.000000000 - 2021-02-05T17:00:00.000013312
# time(250m sensor):  2003-07-09T04:34:00.000026112 - 2021-04-09T13:30:00.000000000
# <xarray.Dataset>
# Dimensions:          (depth: 1, lat: 1, lon: 1, time: 241627)
# Coordinates:
#   * lat              (lat) float64 43.49
#   * lon              (lon) float64 -67.88
#   * depth            (depth) float64 250.0
#   * time             (time) datetime64[ns] 2004-01-01 ... 2020-12-31T23:29:59...
# Data variables:
#     conductivity     (time, depth, lat, lon) float32 ...
# ...

# %% [markdown]
# clean data with qc (quality control)

# %%
# quality check (qc) values
# flag_values :
#     [0 1 2 3]
# flag_meanings :
#     quality_good out_of_range sensor_nonfunctional invalid_input
tqc1 = ds1.temperature_qc
sqc1 = ds1.salinity_qc
rhoqc1 = ds1.sigma_t_qc
t1 = ds1.temperature.where(tqc1<0.1,np.nan)
s1 = ds1.salinity.where(sqc1<0.1,np.nan)
rho1 = ds1.sigma_t.where(rhoqc1<0.1,np.nan)

tqc20 = ds20.temperature_qc
sqc20 = ds20.salinity_qc
rhoqc20 = ds20.sigma_t_qc
t20 = ds20.temperature.where(tqc20<0.1,np.nan)
s20 = ds20.salinity.where(sqc20<0.1,np.nan)
rho20 = ds20.sigma_t.where(rhoqc20<0.1,np.nan)

tqc50 = ds50.temperature_qc
sqc50 = ds50.salinity_qc
rhoqc50 = ds50.sigma_t_qc
t50 = ds50.temperature.where(tqc50<0.1,np.nan)
s50 = ds50.salinity.where(sqc50<0.1,np.nan)
rho50 = ds50.sigma_t.where(rhoqc50<0.1,np.nan)

tqc100 = ds100.temperature_qc
sqc100 = ds100.salinity_qc
rhoqc100 = ds100.sigma_t_qc
t100 = ds100.temperature.where(tqc100<0.1,np.nan)
s100 = ds100.salinity.where(sqc100<0.1,np.nan)
rho100 = ds100.sigma_t.where(rhoqc100<0.1,np.nan)

tqc150 = ds150.temperature_qc
sqc150 = ds150.salinity_qc
rhoqc150 = ds150.sigma_t_qc
t150 = ds150.temperature.where(tqc150<0.1,np.nan)
s150 = ds150.salinity.where(sqc150<0.1,np.nan)
rho150 = ds150.sigma_t.where(rhoqc150<0.1,np.nan)

tqc200 = ds200.temperature_qc
sqc200 = ds200.salinity_qc
rhoqc200 = ds200.sigma_t_qc
t200 = ds200.temperature.where(tqc200<0.1,np.nan)
s200 = ds200.salinity.where(sqc200<0.1,np.nan)
rho200 = ds200.sigma_t.where(rhoqc200<0.1,np.nan)

tqc250 = ds250.temperature_qc
sqc250 = ds250.salinity_qc
rhoqc250 = ds250.sigma_t_qc
t250 = ds250.temperature.where(tqc250<0.1,np.nan)
s250 = ds250.salinity.where(sqc250<0.1,np.nan)
rho250 = ds250.sigma_t.where(rhoqc250<0.1,np.nan)

# %% [markdown]
# plot monthly time series, 2004-2012 is a good time when all 6 sensors have continuous good measurements. There are gaps after 2012.

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))
t1.resample(time='M').mean('time').plot(ax=axs[0],label='1m')
t50.resample(time='M').mean('time').plot(ax=axs[0],label='50m')
t100.resample(time='M').mean('time').plot(ax=axs[0],label='100m')
t150.resample(time='M').mean('time').plot(ax=axs[0],label='150m')
t200.resample(time='M').mean('time').plot(ax=axs[0],label='200m')
t250.resample(time='M').mean('time').plot(ax=axs[0],label='250m',color='k')
axs[0].legend()
axs[0].grid()

s1.resample(time='M').mean('time').plot(ax=axs[1],label='1m')
s50.resample(time='M').mean('time').plot(ax=axs[1],label='50m')
s100.resample(time='M').mean('time').plot(ax=axs[1],label='100m')
s150.resample(time='M').mean('time').plot(ax=axs[1],label='150m')
s200.resample(time='M').mean('time').plot(ax=axs[1],label='200m')
s250.resample(time='M').mean('time').plot(ax=axs[1],label='250m',color='k')
axs[1].legend()
axs[1].grid()

rho1.resample(time='M').mean('time').plot(ax=axs[2],label='1m')
rho50.resample(time='M').mean('time').plot(ax=axs[2],label='50m')
rho100.resample(time='M').mean('time').plot(ax=axs[2],label='100m')
rho150.resample(time='M').mean('time').plot(ax=axs[2],label='150m')
rho200.resample(time='M').mean('time').plot(ax=axs[2],label='200m')
rho250.resample(time='M').mean('time').plot(ax=axs[2],label='250m',color='k')
axs[2].legend()
axs[2].grid()

# %%
depth = np.array([1,20,50,100,150,200,250])
temp_av = np.array([t1.sel(time=slice('2004','2012')).mean('time').squeeze(),
                    t20.sel(time=slice('2004','2012')).mean('time').squeeze(),
                    t50.sel(time=slice('2004','2012')).mean('time').squeeze(),
                    t100.sel(time=slice('2004','2012')).mean('time').squeeze(),
                    t150.sel(time=slice('2004','2012')).mean('time').squeeze(),
                    t200.sel(time=slice('2004','2012')).mean('time').squeeze(),
                    t250.sel(time=slice('2004','2012')).mean('time').squeeze()])
temp_av
# Out:
# array([10.100255 ,  8.227865 ,  6.8374543,  7.029403 ,  7.4593644,
#         7.8718176,  7.9794683], dtype=float32)

# %%
# monthly climatology temp from http://gyre.umeoce.maine.edu/list_clim.php?site=M01
t1 = np.array([5.9,4.4,3.9,4.8,7.5,11.5,15.6,17.0,15.5,12.7,10.1,8.1])
t20 = np.array([6.0,4.5,4.0,4.5,6.3,8.4,9.6,11.4,13.0,12.3,10.1,8.1])
t50 = np.array([6.3,4.9,4.3,4.4,5.2,6.1,6.5,7.3,8.5,9.6,9.8,8.2])
t100 = np.array([7.6,6.9,6.4,6.0,6.0,6.5,6.5,6.6,6.9,7.4,8.1,8.3])
t150 = np.array([7.8,8.0,7.7,7.0,6.7,7.2,7.1,7.0,7.1,7.3,7.6,7.8])
t200 = np.array([8.0,8.1,8.0,7.9,7.7,7.6,7.7,7.8,7.9,8.0,8.0,8.0])
t250 = np.array([8.1,8.1,8.1,8.1,7.8,7.7,7.8,7.9,8.1,8.2,8.2,8.1])

temp = np.stack((t1,t20,t50,t100,t150,t200,t250))
temp.mean(axis=1)
# Out:
# array([9.75      , 8.18333333, 6.75833333, 6.93333333, 7.35833333,
#        7.89166667, 8.01666667])

# %% [markdown]
# # make pics
# compare my computed depth profile with monthly climatology av. depth profile from http://gyre.umeoce.maine.edu/list_clim.php?site=M01 (the web does not state what time period for monthly climatology)

# %%
fig, axs = plt.subplots(1,1)
axs.plot(temp_av,depth,color='b',marker='*',label='mine')
axs.plot(temp.mean(axis=1),depth,color='r',marker='*',label='web')
axs.invert_yaxis()
axs.legend()
axs.grid()
axs.set_title('temp prof from Buoy Mooring M01')
# Out:
# Text(0.5, 1.0, 'temp prof from Buoy Mooring M01')

# %% [markdown]
# # Appendix: plot raw time series plot

# %%
t1.std(),t1.mean()
# Out:
# (<xarray.DataArray 'temperature' ()>
#  array(4.80942535),
#  <xarray.DataArray 'temperature' ()>
#  array(10.545031, dtype=float32))

# %% [markdown]
# obs at 1m

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))

t1n = (t1-t1.mean())/t1.std() # n: normalized 
s1n = (s1-s1.mean())/s1.std()
rho1n = (rho1-rho1.mean())/rho1.std()

t1n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='r', 
                                        marker='*', markersize=3, linewidth=0)
s1n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='b', 
                                        marker='*', markersize=3, linewidth=0)
rho1n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='k', 
                                          marker='*', markersize=3, linewidth=0)
axs[0].grid()

t1n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='r', 
                                        marker='*', markersize=3, linewidth=0)
s1n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='b', 
                                        marker='*', markersize=3, linewidth=0)
rho1n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='k', 
                                          marker='*', markersize=3, linewidth=0)
axs[1].grid()

t1n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='r', 
                                        marker='*', markersize=3, linewidth=0)
s1n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='b', 
                                        marker='*', markersize=3, linewidth=0)
rho1n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='k', 
                                          marker='*', markersize=3, linewidth=0)
axs[2].grid()

# %% [markdown]
# obs at 20 m

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))

t20n = (t20-t20.mean())/t20.std()
s20n = (s20-s20.mean())/s20.std()
rho20n = (rho20-rho20.mean())/rho20.std()

t20n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='r', 
                                         marker='*', markersize=3, linewidth=0)
s20n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='b', 
                                         marker='*', markersize=3, linewidth=0)
rho20n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='k', 
                                           marker='*', markersize=3, linewidth=0)
axs[0].grid()

t20n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='r', 
                                         marker='*', markersize=3, linewidth=0)
s20n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='b', 
                                         marker='*', markersize=3, linewidth=0)
rho20n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='k', 
                                           marker='*', markersize=3, linewidth=0)
axs[1].grid()

t20n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='r', 
                                         marker='*', markersize=3, linewidth=0)
s20n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='b', 
                                         marker='*', markersize=3, linewidth=0)
rho20n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='k', 
                                           marker='*', markersize=3, linewidth=0)
axs[2].grid()

# %% [markdown]
# obs at 50m

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))

t50n = (t50-t50.mean())/t50.std()
s50n = (s50-s50.mean())/s50.std()
rho50n = (rho50-rho50.mean())/rho50.std()

t50n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='r', 
                                         marker='*', markersize=3, linewidth=0)
s50n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='b', 
                                         marker='*', markersize=3, linewidth=0)
rho50n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='k', 
                                           marker='*', markersize=3, linewidth=0)
axs[0].grid()

t50n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='r', 
                                         marker='*', markersize=3, linewidth=0)
s50n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='b', 
                                         marker='*', markersize=3, linewidth=0)
rho50n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='k', 
                                           marker='*', markersize=3, linewidth=0)
axs[1].grid()

t50n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='r', 
                                         marker='*', markersize=3, linewidth=0)
s50n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='b', 
                                         marker='*', markersize=3, linewidth=0)
rho50n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='k', 
                                           marker='*', markersize=3, linewidth=0)
axs[2].grid()

# %% [markdown]
# obs at 100m

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))

t100n = (t100-t100.mean())/t100.std()
s100n = (s100-s100.mean())/s100.std()
rho100n = (rho100-rho100.mean())/rho100.std()

t100n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s100n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho100n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[0].grid()

t100n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s100n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho100n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[1].grid()

t100n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s100n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho100n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[2].grid()

# %% [markdown]
# obs at 150m, good year: 2004-2012, 2014-2015, 2018-2019

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))

t150n = (t150-t150.mean())/t150.std()
s150n = (s150-s150.mean())/s150.std()
rho150n = (rho150-rho150.mean())/rho150.std()

t150n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s150n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho150n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[0].grid()

t150n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s150n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho150n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[1].grid()

t150n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s150n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho150n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[2].grid()

# %% [markdown]
# obs at 200m, good obs year: 2004-2012, 2014-2015, 2018-2019

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))

t200n = (t200-t200.mean())/t200.std()
s200n = (s200-s200.mean())/s200.std()
rho200n = (rho200-rho200.mean())/rho200.std()

t200n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s200n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho200n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[0].grid()

t200n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='r', marker='*', 
                                          markersize=3, linewidth=0)
s200n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='b', marker='*', 
                                          markersize=3, linewidth=0)
rho200n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='k', marker='*', 
                                            markersize=3, linewidth=0)
axs[1].grid()

t200n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s200n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho200n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[2].grid()

# %% [markdown]
# obs at 250m, good obs year: 2004-2007, 2010-2012, 2016, 2019, 2020

# %%
fig, axs = plt.subplots(3,1,figsize=(20,15))

t250n = (t250-t250.mean())/t250.std()
s250n = (s250-s250.mean())/s250.std()
rho250n = (rho250-rho250.mean())/rho250.std()

t250n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s250n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho250n.sel(time=slice('2004','2009')).plot(ax=axs[0], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[0].grid()

t250n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s250n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho250n.sel(time=slice('2010','2015')).plot(ax=axs[1], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[1].grid()

t250n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='r', 
                                          marker='*', markersize=3, linewidth=0)
s250n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='b', 
                                          marker='*', markersize=3, linewidth=0)
rho250n.sel(time=slice('2016','2020')).plot(ax=axs[2], color='k', 
                                            marker='*', markersize=3, linewidth=0)
axs[2].grid()

# %%
ds1.time.diff(dim='time').plot.line(marker='*')
ds2.time.diff(dim='time').plot.line(marker='*')
ds3.time.diff(dim='time').plot.line(marker='*')
ds4.time.diff(dim='time').plot.line(marker='*')
ds5.time.diff(dim='time').plot.line(marker='*')
ds6.time.diff(dim='time').plot.line(marker='*')
# ds1.temperature_qc.isel(depth=0,lat=0,lon=0).plot(marker='*',markersize=2)

# %%
ds1.sel(time=slice('2010-06-09','2010-06-10')).time.diff('time').plot(marker='*')
