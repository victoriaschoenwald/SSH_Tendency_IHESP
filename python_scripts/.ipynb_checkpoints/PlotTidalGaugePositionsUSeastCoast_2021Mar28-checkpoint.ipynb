# %% [markdown]
# # === readme ===
# descrip: python template for jupyter notebook
#
# update history: <br>
# v1.0 DL 2020Oct07
#
# extra notes: <br>
# use jupyter lab and Abishek's python virtual env (/ihesp/shared/conda/envs/jupyterlab_env) for dask <br>

# %% [markdown]
# ##  === import modules ===

# %%
# general python packages
import numpy as np
# import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import cartopy.crs as ccrs

# python GCM(POP) packages
# import xgcm
# import pop_tools
# import xesmf as xe
# import seawater as sw

# dask jupyter lab packages
# from dask.distributed import Client
# from dask.distributed import performance_report

# file name with time packages
# from itertools import product
# from cftime import DatetimeNoLeap

# %%
# fig, ax = plt.subplots(1,1)
pc = ccrs.PlateCarree()
# proj = cartopy.crs.Robinson()
fig = plt.figure(figsize=(12, 6))

# historic LR
ax1 = plt.subplot(111,projection=pc)
# subplt1=ax1.pcolormesh(ds_LR.lon, ds_LR.lat, ds_LR.hmxl_clim_hs_LR,
#                        vmin=0,vmax=250,transform=pc,cmap='jet')
ax1.coastlines()
ax1.set_title('historic (2004-2017) - LR')
# Out:
# Text(0.5, 1.0, 'historic (2004-2017) - LR')
# /scratch/group/ihesp/shared/conda/envs/envMar25/lib/python3.7/site-packages/cartopy/io/__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/physical/ne_110m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /scratch/group/ihesp/shared/conda/envs/envMar25/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# /scratch/group/ihesp/shared/conda/envs/envMar25/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
# ...
