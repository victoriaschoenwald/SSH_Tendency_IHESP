# %% [markdown]
# # readme
# descrip: check Daily Merged Files from CESM diagnostics (told by Abishek) for iHESP HRMIP and LR
#
# update history: <br>
# v1.0 DL 2021Mar26 <br>
#
# extra notes: <br>

# %% [markdown]
# # import modules

# %%
# general python packages
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# import cartopy.crs as ccrs
# from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# python GCM(POP) packages
# import xgcm
# import pop_tools
# import xesmf as xe

# dask jupyter lab packages
# from dask.distributed import Client
# from dask.distributed import performance_report

# file name with time packages
# from itertools import product
# from cftime import DatetimeNoLeap

# %% [markdown]
# # incorporate dask

# %%
# client = Client("tcp://10.72.13.61:36552")
# client

# %% [markdown]
# # define parameters
# tr: transient <br>
# c: control <br>
# HR: HRMIP <br>
# LR: low resolution <br>

# %% [markdown]
# transient (tr) HR

# %%
indir_tr_HR = '/ihesp/archive/HRMIP/B.E.13.B1950TRC5.ne120_t12.cesm-ihesp-1950-2050.013/ocn/hist/daily_merged/'
infile_tr_mon_HR = indir_tr_HR + 'B.E.13.B1950TRC5.ne120_t12.cesm-ihesp-1950-2050.013.pop.h.2050-12.nc'
infile_tr_day_HR = indir_tr_HR +'B.E.13.B1950TRC5.ne120_t12.cesm-ihesp-1950-2050.013.pop.h.nday1.1950-01.nc'

# %%
ds_tr_mon_HR = xr.open_dataset(infile_tr_mon_HR)
ds_tr_mon_HR
# Out:
# <xarray.Dataset>
# Dimensions:             (d2: 2, nlat: 2400, nlon: 3600, time: 1, z_t: 62, z_t_150m: 15, z_w: 62, z_w_bot: 62, z_w_top: 62)
# Coordinates:
#   * time                (time) object 2050-12-17 00:00:00
#   * z_t                 (z_t) float32 500.0 1500.0 ... 562499.06 587499.06
#   * z_t_150m            (z_t_150m) float32 500.0 1500.0 ... 13500.0 14500.0
#   * z_w                 (z_w) float32 0.0 1000.0 2000.0 ... 549999.06 574999.06
#   * z_w_top             (z_w_top) float32 0.0 1000.0 ... 549999.06 574999.06
#   * z_w_bot             (z_w_bot) float32 1000.0 2000.0 ... 574999.06 599999.06
#     ULONG               (nlat, nlon) float64 ...
#     ULAT                (nlat, nlon) float64 ...
#     TLONG               (nlat, nlon) float64 ...
#     TLAT                (nlat, nlon) float64 ...
# Dimensions without coordinates: d2, nlat, nlon
# Data variables:
#     time_bound          (time, d2) object ...
#     dz                  (z_t) float32 ...
# ...

# %%
ds_tr_day_HR = xr.open_dataset(infile_tr_day_HR)
ds_tr_day_HR
# Out:
# <xarray.Dataset>
# Dimensions:             (d2: 2, nlat: 2400, nlon: 3600, time: 1, z_t: 62, z_t_150m: 15, z_w: 62, z_w_bot: 62, z_w_top: 62)
# Coordinates:
#   * time                (time) object 1950-01-17 00:00:00
#   * z_t                 (z_t) float32 500.0 1500.0 ... 562499.06 587499.06
#   * z_t_150m            (z_t_150m) float32 500.0 1500.0 ... 13500.0 14500.0
#   * z_w                 (z_w) float32 0.0 1000.0 2000.0 ... 549999.06 574999.06
#   * z_w_top             (z_w_top) float32 0.0 1000.0 ... 549999.06 574999.06
#   * z_w_bot             (z_w_bot) float32 1000.0 2000.0 ... 574999.06 599999.06
#     ULONG               (nlat, nlon) float64 ...
#     ULAT                (nlat, nlon) float64 ...
#     TLONG               (nlat, nlon) float64 ...
#     TLAT                (nlat, nlon) float64 ...
# Dimensions without coordinates: d2, nlat, nlon
# Data variables:
#     time_bound          (time, d2) object ...
#     dz                  (z_t) float32 ...
# ...

# %% [markdown]
# control (c) HR

# %%
indir_c_HR = '/ihesp/archive/HRMIP/B.E.13.B1950C5.ne120_t12.cesm-ihesp-1950cntl.013/ocn/hist/daily_merged/'
infile_c_mon_HR = indir_c_HR + 'B.E.13.B1950C5.ne120_t12.cesm-ihesp-1950cntl.013.pop.h.0155-12.nc'
infile_c_day_HR = indir_c_HR + 'B.E.13.B1950C5.ne120_t12.cesm-ihesp-1950cntl.013.pop.h.nday1.0055-01.nc'

# %%
ds_c_mon_HR = xr.open_dataset(infile_c_mon_HR)
ds_c_mon_HR
# Out:
# <xarray.Dataset>
# Dimensions:             (d2: 2, nlat: 2400, nlon: 3600, time: 1, z_t: 62, z_t_150m: 15, z_w: 62, z_w_bot: 62, z_w_top: 62)
# Coordinates:
#   * time                (time) object 0155-12-17 00:00:00
#   * z_t                 (z_t) float32 500.0 1500.0 ... 562499.06 587499.06
#   * z_t_150m            (z_t_150m) float32 500.0 1500.0 ... 13500.0 14500.0
#   * z_w                 (z_w) float32 0.0 1000.0 2000.0 ... 549999.06 574999.06
#   * z_w_top             (z_w_top) float32 0.0 1000.0 ... 549999.06 574999.06
#   * z_w_bot             (z_w_bot) float32 1000.0 2000.0 ... 574999.06 599999.06
#     ULONG               (nlat, nlon) float64 ...
#     ULAT                (nlat, nlon) float64 ...
#     TLONG               (nlat, nlon) float64 ...
#     TLAT                (nlat, nlon) float64 ...
# Dimensions without coordinates: d2, nlat, nlon
# Data variables:
#     time_bound          (time, d2) object ...
#     dz                  (z_t) float32 ...
# ...

# %%
ds_c_day_HR = xr.open_dataset(infile_c_day_HR)
ds_c_day_HR
# Out:
# <xarray.Dataset>
# Dimensions:             (d2: 2, nlat: 2400, nlon: 3600, time: 1, z_t: 62, z_t_150m: 15, z_w: 62, z_w_bot: 62, z_w_top: 62)
# Coordinates:
#   * time                (time) object 0055-01-17 00:00:00
#   * z_t                 (z_t) float32 500.0 1500.0 ... 562499.06 587499.06
#   * z_t_150m            (z_t_150m) float32 500.0 1500.0 ... 13500.0 14500.0
#   * z_w                 (z_w) float32 0.0 1000.0 2000.0 ... 549999.06 574999.06
#   * z_w_top             (z_w_top) float32 0.0 1000.0 ... 549999.06 574999.06
#   * z_w_bot             (z_w_bot) float32 1000.0 2000.0 ... 574999.06 599999.06
#     ULONG               (nlat, nlon) float64 ...
#     ULAT                (nlat, nlon) float64 ...
#     TLONG               (nlat, nlon) float64 ...
#     TLAT                (nlat, nlon) float64 ...
# Dimensions without coordinates: d2, nlat, nlon
# Data variables:
#     time_bound          (time, d2) object ...
#     dz                  (z_t) float32 ...
# ...

# %% [markdown]
# transient (tr) LR

# %%
indir_tr_LR = '/ihesp/archive/LR/b.e13.B1950TRC5.ne30_g16.ihesp24_1950-2050.002/ocn/hist/daily_merged/'
# no netcdf files under daily_merged

# %% [markdown]
# control (c) LR

# %%
indir_c_LR = '/ihesp/archive/LR/b.e13.B1950C5.ne30_g16.ihesp24_1950cntl.002/ocn/hist/daily_merged/'
# no netcdf files under daily_merged
