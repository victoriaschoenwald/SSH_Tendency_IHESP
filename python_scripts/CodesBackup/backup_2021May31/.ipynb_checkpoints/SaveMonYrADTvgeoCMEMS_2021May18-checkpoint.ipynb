# %% [markdown]
# # readme
# descrip: compte CMEMS (AVISO) daily dynamical sea level (DSL = ADT - ADV global mean) and save the data to nc files for loop current eddy shedding <br>
#
# update history: <br>
# v1.0 DL 2021Nov12 first creation <br>
#
# extra notes: <br>

# %% [markdown]
# # import modules

# %%
# general python packages
import numpy as np
import xarray as xr
# import pandas as pd
import matplotlib.pyplot as plt
# import matplotlib.dates as mdates
# %matplotlib inline
# import cartopy.crs as ccrs
# from cartopy.mpl.geoaxes import GeoAxes
# from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
# from mpl_toolkits.axes_grid1 import AxesGrid

# python GCM(POP) packages
# import xgcm
# import pop_tools
# import xesmf as xe
import glob

# from eofs.xarray import Eof

# dask jupyter lab packages
from dask.distributed import Client
# from dask.distributed import performance_report

# file name with time packages
from itertools import product
# from cftime import DatetimeNoLeap

# %% [markdown]
# # incorporate dask

# %%
client = Client("tcp://10.73.1.44:40379")
client
# Out:
# <Client: 'tcp://10.73.1.44:40379' processes=16 threads=16, memory=316.64 GiB>

# %%
date_str = '2021May18'

yrs = np.arange(1993,2019+1)
mons = np.arange(1,12+1)
chunk_size = {'latitude':720,'longitude':1440}

# %%
# test 2021Nov12
indir = ('/ihesp/user/dapengli/obs_dat/SEALEVEL_GLO_PHY_L4_REP_OBSERVATIONS_008_047/'
         'dataset_duacs_rep_global_merged_allsat_phy_l4/1993/*/*.nc')
infiles = sorted(glob.glob(indir))
print('total number of files:', len(infiles))
print('first file:', infiles[0])
print('last file:', infiles[-1])

chunk_size = {'time':1}
ds_ssh_obs = xr.open_mfdataset(infiles, compat="override", combine="by_coords", 
                       data_vars="minimal", coords="minimal",  chunks=chunk_size, parallel=True)
print(ds)
fig, axs = plt.subplots(2,2,figsize=(10,5))
ds_ssh_obs.adt.isel(time=0).plot(ax=axs[0,0], vmin=-2, vmax=2, cmap='jet') # land is nan
print('land point value:', ds_ssh_obs.adt.isel(time=0).sel(latitude=20, method='nearest').values)
# ds.adt.weighted

weight_ssh_obs = np.cos(np.deg2rad(ds_ssh_obs.latitude))
weight_ssh_obs.name = "weight_ssh_obs"
ssh_gl_av_obs = ds_ssh_obs.adt.weighted(weight_ssh_obs).mean(("longitude", "latitude")).compute() # unit: m
print(ssh_gl_av_obs.dims)
ssh_gl_av_obs.plot(ax=axs[0,1])

dsl_obs = ds_ssh_obs.adt - ssh_gl_av_obs
dsl_obs.isel(time=0).plot(ax=axs[1,0], vmin=-2, vmax=2, cmap='jet')
dsl_gl_av_obs = dsl_obs.weighted(weight_ssh_obs).mean(("longitude", "latitude"))
dsl_gl_av_obs.plot(ax=axs[1,1])
# Out:
# total number of files: 365
# first file: /ihesp/user/dapengli/obs_dat/SEALEVEL_GLO_PHY_L4_REP_OBSERVATIONS_008_047/dataset_duacs_rep_global_merged_allsat_phy_l4/1993/01/dt_global_allsat_phy_l4_19930101_20190101.nc
# last file: /ihesp/user/dapengli/obs_dat/SEALEVEL_GLO_PHY_L4_REP_OBSERVATIONS_008_047/dataset_duacs_rep_global_merged_allsat_phy_l4/1993/12/dt_global_allsat_phy_l4_19931231_20190101.nc
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440, nv: 2, time: 365)
# Coordinates:
#   * time       (time) datetime64[ns] 1993-01-01 1993-01-02 ... 1993-12-31
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 0.125 0.375 0.625 0.875 ... 359.4 359.6 359.9
#   * nv         (nv) int32 0 1
# Data variables:
#     crs        int32 ...
#     lat_bnds   (latitude, nv) float32 dask.array<chunksize=(720, 2), meta=np.ndarray>
#     lon_bnds   (longitude, nv) float32 dask.array<chunksize=(1440, 2), meta=np.ndarray>
#     err        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     adt        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     sla        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     cdm_data_type:                   Grid
#     comment:                         Sea Surface Height measured by Altimetry...
#     contact:                         servicedesk.cmems@mercator-ocean.eu
#     creator_email:                   servicedesk.cmems@mercator-ocean.eu
#     ...                              ...
#     summary:                         SSALTO/DUACS Delayed-Time Level-4 sea su...
#     time_coverage_duration:          P1D
#     time_coverage_end:               1993-01-01T00:00:00Z
#     time_coverage_resolution:        P1D
#     time_coverage_start:             1993-01-01T00:00:00Z
#     title:                           DT merged all satellites Global Ocean Gr...
# land point value: [nan nan nan ... nan nan nan]
# ('time',)

# %% [markdown]
# # data analysis

# %%
# %%time
indir = ('/ihesp/user/dapengli/obs_dat/SEALEVEL_GLO_PHY_L4_REP_OBSERVATIONS_008_047/'
         'dataset_duacs_rep_global_merged_allsat_phy_l4/')
outdir = ('/scratch/user/dapengli/Projects4iHESP/Project_SeaLevelUSEastCoast_2021Mar30/'
          'data_after_manipulation/ADT_Vgeo_CMEMS/')

for iyr in yrs:
    for imon in mons:
        infiles = indir + str(iyr) + '/' + str(imon).zfill(2) + '/*.nc'
        ds = xr.open_mfdataset(infiles, compat="override", combine="by_coords", 
             data_vars="minimal", coords="minimal",  chunks=chunk_size, parallel=True)
        print('av.'+str(iyr)+str(imon).zfill(2)+', total days:'+str(ds.time.size))
        ds_rs = ds.resample(time='M').mean('time') # time='M', month end time
        
        outfile = (outdir + 'dt_global_allsat_phy_l4_' + str(iyr) + str(imon).zfill(2)
                   +'_'+date_str+'.nc')
        ds_rs.to_netcdf(path=outfile, mode='w', format='NETCDF4', compute=True)
        del infiles, ds, outfile, ds_rs
# Out:
# av.199301, total days:31
# av.199302, total days:28
# av.199303, total days:31
# av.199304, total days:30
# av.199305, total days:31
# av.199306, total days:30
# av.199307, total days:31
# av.199308, total days:31
# av.199309, total days:30
# av.199310, total days:31
# av.199311, total days:30
# av.199312, total days:31
# av.199401, total days:31
# av.199402, total days:28
# av.199403, total days:31
# av.199404, total days:30
# av.199405, total days:31
# av.199406, total days:30
# av.199407, total days:31
# av.199408, total days:31
# av.199409, total days:30
# av.199410, total days:31
# av.199411, total days:30
# av.199412, total days:31
# av.199501, total days:31
# av.199502, total days:28
# av.199503, total days:31
# av.199504, total days:30
# av.199505, total days:31
# av.199506, total days:30
# av.199507, total days:31
# av.199508, total days:31
# av.199509, total days:30
# av.199510, total days:31
# av.199511, total days:30
# av.199512, total days:31
# av.199601, total days:31
# av.199602, total days:29
# av.199603, total days:31
# av.199604, total days:30
# av.199605, total days:31
# av.199606, total days:30
# av.199607, total days:31
# av.199608, total days:31
# av.199609, total days:30
# av.199610, total days:31
# av.199611, total days:30
# av.199612, total days:31
# av.199701, total days:31
# av.199702, total days:28
# av.199703, total days:31
# av.199704, total days:30
# av.199705, total days:31
# av.199706, total days:30
# av.199707, total days:31
# av.199708, total days:31
# av.199709, total days:30
# av.199710, total days:31
# av.199711, total days:30
# av.199712, total days:31
# av.199801, total days:31
# av.199802, total days:28
# av.199803, total days:31
# av.199804, total days:30
# av.199805, total days:31
# av.199806, total days:30
# av.199807, total days:31
# av.199808, total days:31
# av.199809, total days:30
# av.199810, total days:31
# av.199811, total days:30
# av.199812, total days:31
# av.199901, total days:31
# av.199902, total days:28
# av.199903, total days:31
# av.199904, total days:30
# av.199905, total days:31
# av.199906, total days:30
# av.199907, total days:31
# av.199908, total days:31
# av.199909, total days:30
# av.199910, total days:31
# av.199911, total days:30
# av.199912, total days:31
# av.200001, total days:31
# av.200002, total days:29
# av.200003, total days:31
# av.200004, total days:30
# av.200005, total days:31
# av.200006, total days:30
# av.200007, total days:31
# av.200008, total days:31
# av.200009, total days:30
# av.200010, total days:31
# av.200011, total days:30
# av.200012, total days:31
# av.200101, total days:31
# av.200102, total days:28
# av.200103, total days:31
# av.200104, total days:30
# av.200105, total days:31
# av.200106, total days:30
# av.200107, total days:31
# av.200108, total days:31
# av.200109, total days:30
# av.200110, total days:31
# av.200111, total days:30
# av.200112, total days:31
# av.200201, total days:31
# av.200202, total days:28
# av.200203, total days:31
# av.200204, total days:30
# av.200205, total days:31
# av.200206, total days:30
# av.200207, total days:31
# av.200208, total days:31
# av.200209, total days:30
# av.200210, total days:31
# av.200211, total days:30
# av.200212, total days:31
# av.200301, total days:31
# av.200302, total days:28
# av.200303, total days:31
# av.200304, total days:30
# av.200305, total days:31
# av.200306, total days:30
# av.200307, total days:31
# av.200308, total days:31
# av.200309, total days:30
# av.200310, total days:31
# av.200311, total days:30
# av.200312, total days:31
# av.200401, total days:31
# av.200402, total days:29
# av.200403, total days:31
# av.200404, total days:30
# av.200405, total days:31
# av.200406, total days:30
# av.200407, total days:31
# av.200408, total days:31
# av.200409, total days:30
# av.200410, total days:31
# av.200411, total days:30
# av.200412, total days:31
# av.200501, total days:31
# av.200502, total days:28
# av.200503, total days:31
# av.200504, total days:30
# av.200505, total days:31
# av.200506, total days:30
# av.200507, total days:31
# av.200508, total days:31
# av.200509, total days:30
# av.200510, total days:31
# av.200511, total days:30
# av.200512, total days:31
# av.200601, total days:31
# av.200602, total days:28
# av.200603, total days:31
# av.200604, total days:30
# av.200605, total days:31
# av.200606, total days:30
# av.200607, total days:31
# av.200608, total days:31
# av.200609, total days:30
# av.200610, total days:31
# av.200611, total days:30
# av.200612, total days:31
# av.200701, total days:31
# av.200702, total days:28
# av.200703, total days:31
# av.200704, total days:30
# av.200705, total days:31
# av.200706, total days:30
# av.200707, total days:31
# av.200708, total days:31
# av.200709, total days:30
# av.200710, total days:31
# av.200711, total days:30
# av.200712, total days:31
# av.200801, total days:31
# av.200802, total days:29
# av.200803, total days:31
# av.200804, total days:30
# av.200805, total days:31
# av.200806, total days:30
# av.200807, total days:31
# av.200808, total days:31
# av.200809, total days:30
# av.200810, total days:31
# av.200811, total days:30
# av.200812, total days:31
# av.200901, total days:31
# av.200902, total days:28
# av.200903, total days:31
# av.200904, total days:30
# av.200905, total days:31
# av.200906, total days:30
# av.200907, total days:31
# av.200908, total days:31
# av.200909, total days:30
# av.200910, total days:31
# av.200911, total days:30
# av.200912, total days:31
# av.201001, total days:31
# av.201002, total days:28
# av.201003, total days:31
# av.201004, total days:30
# av.201005, total days:31
# av.201006, total days:30
# av.201007, total days:31
# av.201008, total days:31
# av.201009, total days:30
# av.201010, total days:31
# av.201011, total days:30
# av.201012, total days:31
# av.201101, total days:31
# av.201102, total days:28
# av.201103, total days:31
# av.201104, total days:30
# av.201105, total days:31
# av.201106, total days:30
# av.201107, total days:31
# av.201108, total days:31
# av.201109, total days:30
# av.201110, total days:31
# av.201111, total days:30
# av.201112, total days:31
# av.201201, total days:31
# av.201202, total days:29
# av.201203, total days:31
# av.201204, total days:30
# av.201205, total days:31
# av.201206, total days:30
# av.201207, total days:31
# av.201208, total days:31
# av.201209, total days:30
# av.201210, total days:31
# av.201211, total days:30
# av.201212, total days:31
# av.201301, total days:31
# av.201302, total days:28
# av.201303, total days:31
# av.201304, total days:30
# av.201305, total days:31
# av.201306, total days:30
# av.201307, total days:31
# av.201308, total days:31
# av.201309, total days:30
# av.201310, total days:31
# av.201311, total days:30
# av.201312, total days:31
# av.201401, total days:31
# av.201402, total days:28
# av.201403, total days:31
# av.201404, total days:30
# av.201405, total days:31
# av.201406, total days:30
# av.201407, total days:31
# av.201408, total days:31
# av.201409, total days:30
# av.201410, total days:31
# av.201411, total days:30
# av.201412, total days:31
# av.201501, total days:31
# av.201502, total days:28
# av.201503, total days:31
# av.201504, total days:30
# av.201505, total days:31
# av.201506, total days:30
# av.201507, total days:31
# av.201508, total days:31
# av.201509, total days:30
# av.201510, total days:31
# av.201511, total days:30
# av.201512, total days:31
# av.201601, total days:31
# av.201602, total days:29
# av.201603, total days:31
# av.201604, total days:30
# av.201605, total days:31
# av.201606, total days:30
# av.201607, total days:31
# av.201608, total days:31
# av.201609, total days:30
# av.201610, total days:31
# av.201611, total days:30
# av.201612, total days:31
# av.201701, total days:31
# av.201702, total days:28
# av.201703, total days:31
# av.201704, total days:30
# av.201705, total days:31
# av.201706, total days:30
# av.201707, total days:31
# av.201708, total days:31
# av.201709, total days:30
# av.201710, total days:31
# av.201711, total days:30
# av.201712, total days:31
# av.201801, total days:31
# av.201802, total days:28
# av.201803, total days:31
# av.201804, total days:30
# av.201805, total days:31
# av.201806, total days:30
# av.201807, total days:31
# av.201808, total days:31
# av.201809, total days:30
# av.201810, total days:31
# av.201811, total days:30
# av.201812, total days:31
# av.201901, total days:31
# av.201902, total days:28
# av.201903, total days:31
# av.201904, total days:30
# av.201905, total days:31
# av.201906, total days:30
# av.201907, total days:31
# av.201908, total days:31
# av.201909, total days:30
# av.201910, total days:31
# av.201911, total days:30
# av.201912, total days:31
# CPU times: user 2min 19s, sys: 5.28 s, total: 2min 24s
# Wall time: 20min 18s

# %% [markdown]
# resample monthly to yearly data

# %%
outdir = ('/scratch/user/dapengli/Projects4iHESP/Project_SeaLevelUSEastCoast_2021Mar30/'
          'data_after_manipulation/ADT_Vgeo_CMEMS/')
infiles = [outdir + 'dt_global_allsat_phy_l4_' + str(iyr) + str(imon).zfill(2) + 
           '_2021May18.nc' for iyr, imon in product(yrs, mons)]
outfile = (outdir + 'dt_global_allsat_phy_l4_1993-2019_'+date_str+'.nc')

# %%
ds = xr.open_mfdataset(infiles, compat="override", combine="by_coords", 
             data_vars="minimal", coords="minimal",  chunks=chunk_size, parallel=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440, nv: 2, time: 324)
# Coordinates:
#   * time       (time) datetime64[ns] 1993-01-31 1993-02-28 ... 2019-12-31
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 0.125 0.375 0.625 0.875 ... 359.4 359.6 359.9
#   * nv         (nv) int32 0 1
# Data variables:
#     crs        (time) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#     lat_bnds   (time, latitude, nv) float32 dask.array<chunksize=(1, 720, 2), meta=np.ndarray>
#     lon_bnds   (time, longitude, nv) float32 dask.array<chunksize=(1, 1440, 2), meta=np.ndarray>
#     err        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     adt        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     sla        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>

# %%
ds_rs = ds.resample(time='A').mean('time') # time='A' year end 
ds_rs
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440, nv: 2, time: 27)
# Coordinates:
#   * time       (time) datetime64[ns] 1993-12-31 1994-12-31 ... 2019-12-31
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 0.125 0.375 0.625 0.875 ... 359.4 359.6 359.9
#   * nv         (nv) int32 0 1
# Data variables:
#     crs        (time) float64 dask.array<chunksize=(1,), meta=np.ndarray>
#     lat_bnds   (time, latitude, nv) float32 dask.array<chunksize=(1, 720, 2), meta=np.ndarray>
#     lon_bnds   (time, longitude, nv) float32 dask.array<chunksize=(1, 1440, 2), meta=np.ndarray>
#     err        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     adt        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     sla        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>

# %%
ds_rs.to_netcdf(path=outfile, mode='w', format='NETCDF4', compute=True)

# %% [markdown]
# # Appendix

# %%
iyr=1993
imon=12
infiles = indir + str(iyr) + '/' + str(imon).zfill(2) + '/*.nc'
infiles
# Out:
# '/ihesp/user/dapengli/obs_dat/SEALEVEL_GLO_PHY_L4_REP_OBSERVATIONS_008_047/dataset_duacs_rep_global_merged_allsat_phy_l4/1993/12/*.nc'

# %%
outfile=(outdir+'dt_global_allsat_phy_l4_'+str(iyr)+str(imon).zfill(2)+'_'+date_str+'.nc')
outfile
# Out:
# '/scratch/user/dapengli/Projects4iHESP/Project_SeaLevelUSEastCoast_2021Mar30/data_after_manipulation/ADT_Vgeo_CMEMS/dt_global_allsat_phy_l4_199312_2021May18.nc'

# %%
ds = xr.open_mfdataset(infiles, compat="override", combine="by_coords", data_vars="minimal",
                          coords="minimal",  chunks=chunk_size, parallel=True)
print('av.'+str(iyr)+'-'+str(imon).zfill(2)+', total days:'+str(ds.time.size))
ds
# Out:
# av.1993-12, total days:31
# <xarray.Dataset>
# Dimensions:    (latitude: 720, longitude: 1440, nv: 2, time: 31)
# Coordinates:
#   * time       (time) datetime64[ns] 1993-12-01 1993-12-02 ... 1993-12-31
#   * latitude   (latitude) float32 -89.88 -89.62 -89.38 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 0.125 0.375 0.625 0.875 ... 359.4 359.6 359.9
#   * nv         (nv) int32 0 1
# Data variables:
#     crs        int32 ...
#     lat_bnds   (latitude, nv) float32 dask.array<chunksize=(720, 2), meta=np.ndarray>
#     lon_bnds   (longitude, nv) float32 dask.array<chunksize=(1440, 2), meta=np.ndarray>
#     err        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     adt        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgos       (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     sla        (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     ugosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
#     vgosa      (time, latitude, longitude) float64 dask.array<chunksize=(1, 720, 1440), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     cdm_data_type:                   Grid
#     comment:                         Sea Surface Height measured by Altimetry...
#     contact:                         servicedesk.cmems@mercator-ocean.eu
#     creator_email:                   servicedesk.cmems@mercator-ocean.eu
#     ...                              ...
#     summary:                         SSALTO/DUACS Delayed-Time Level-4 sea su...
#     time_coverage_duration:          P1D
#     time_coverage_end:               1993-12-01T00:00:00Z
#     time_coverage_resolution:        P1D
#     time_coverage_start:             1993-12-01T00:00:00Z
#     title:                           DT merged all satellites Global Ocean Gr...
